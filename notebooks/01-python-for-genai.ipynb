# %% [markdown]
# <a href="https://www.kaggle.com/code/shravankumar147/01-python-for-genai?scriptVersionId=219215378" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # Chapter 1: Introduction to Python

# %% [markdown]
# ## Introduction to Python

# %% [markdown]
# ![image.png](attachment:a142f530-0b4c-4356-aaca-fe30974fd643.png)

# %%
from IPython.display import display, HTML

# %%
display(HTML('''
<iframe 
    src="https://www.canva.com/design/DAGdMeMcQg4/C_E3Af8eJRr8INbj6bQdFA/view?embed" 
    width="1200" 
    height="720"
    frameborder="0"
></iframe>
'''))
# Out:
# <iframe
#     src="https://www.canva.com/design/DAGdMeMcQg4/C_E3Af8eJRr8INbj6bQdFA/view?embed"
#     width="1200"
#     height="720"
#     frameborder="0"
# ></iframe>

# %% [markdown]
# [Open Public Canva Design](https://www.canva.com/design/DAGdMeMcQg4/C_E3Af8eJRr8INbj6bQdFA/view?utm_content=DAGdMeMcQg4&utm_campaign=designshare&utm_medium=link2&utm_source=uniquelinks&utlId=h634cc69628)

# %% [markdown]
# ## Let dive in and start coding in python

# %% [markdown]
# **Basic Syntax: Getting Started**
#
# Let’s start with a simple “Hello, World!” program to introduce you to Python’s syntax.
#
# ```python
# print("Hello, World!")
# ```
#
# This code prints the text “Hello, World!” to the console. The `print()` function is used to display output in Python.
#
# ---

# %%
print("Hello, World!")

# %% [markdown]
# **Variables and Data Types**
#
# In Python, variables are used to store data. Python supports several data types, including:
#
# - **Integers**: Whole numbers (e.g., `5`, `3`).
# - **Floats**: Decimal numbers (e.g., `3.14`, `2.5`).
# - **Strings**: Sequences of characters (e.g., `"Hello"`, `'AI'`).
# - **Booleans**: Logical values (`True` or `False`).
#
# Here’s an example of declaring variables in Python:
#
# ```python
# age = 25# Integer
# pi = 3.14159# Float
# name = "Alice"# String
# is_student = True# Boolean
# ```
#
# ---

# %%
age = 25# Integer
print(age)
print(type(age))

# %%
pi = 3.14159# Float

# %%
name = "Alice"# String

# %%
is_student = True# Boolean

# %% [markdown]
# **Control Flow: Conditional Statements and Loops**
#
# Control flow refers to the order in which statements are executed in a program. Python provides conditional statements and loops to control the flow of execution.
#
# **Conditional Statements: if-else**
#
# Conditional statements allow the program to make decisions based on certain conditions.
#
# ```python
# temperature = 20if temperature > 25:
#     print("It's hot outside!")
# else:
#     print("It's cool outside!")
# ```
#
# **Loops: for and while**
#
# Loops are used to repeat a block of code multiple times.
#
# ```python
# # for loopfor i in range(3):
#     print(i)# Output: 0, 1, 2# while loopcount = 0while count < 3:
#     print(count)# Output: 0, 1, 2    count += 1
# ```
#
# ---

# %%
temperature = 20if temperature > 25:
    print("It's hot outside!")
else:
    print("It's cool outside!")

# %%
# for loopfor i in range(3):
    print(i)# Output: 0, 1, 2# while loopcount = 0while count < 3:
    print(count)# Output: 0, 1, 2    count += 1

# %% [markdown]
# **Functions: Reusable Code Blocks**
#
# Functions are blocks of code that perform a specific task and can be reused throughout the program.
#
# ```python
# def greet(name):
#     print(f"Hello, {name}!")
# greet("Alice")# Output: Hello, Alice!
# ```
#
# ---
#
# **Error Handling: Dealing with Mistakes**
#
# Even the best programmers make mistakes. Python allows you to handle errors gracefully using try-except blocks.
#
# ```python
# try:
#     result = 10 / 0
# except ZeroDivisionError:
#     print("Error: Division by zero!")
# ```
#
# ---

# %%
def greet(name):
    print(f"Hello, {name}!")
greet("Alice")# Output: Hello, Alice!

# %%
try:
    result = 10 / 0
except ZeroDivisionError:
    print("Error: Division by zero!")

# %% [markdown]
# **The Python Ecosystem: Libraries and Tools**
#
# Python’s strength lies in its extensive ecosystem of libraries and tools. Some popular libraries for AI include:
#
# - **TensorFlow**: A popular open-source library for machine learning and deep learning.
# - **PyTorch**: A library for deep learning developed by Facebook’s AI Research lab.
# - **Scikit-learn**: A library for machine learning that provides simple and efficient tools for data analysis.
#
# ---

# %% [markdown]
# Refer:
# * https://www.notion.so/Chapter-1-Introduction-to-Python-6ce77ba70864449294fec642b4087b52
# * https://www.python.org/
# * https://gvanrossum.github.io/
# * https://www.tensorflow.org/
# * https://pytorch.org/
# * https://scikit-learn.org/stable/

# %% [markdown]
# **Conclusion**
#
# In this chapter, we’ve introduced you to the basics of Python, including its syntax, variables, control flow, functions, and error handling. We’ve also touched on Python’s popularity in AI and its extensive ecosystem of libraries and tools.
#
# By mastering these fundamentals, you’ll be well-prepared to dive deeper into Python and explore its applications in AI and beyond. Let’s move on to the next chapter and continue our journey into the world of Python programming!
#
# ---

# %% [markdown]
# **Practice Exercises**
#
# 1. Write a Python program that prints “Welcome to Python!”.
# 2. Declare variables of different data types and print their values.
# 3. Write a conditional statement that checks if a number is positive, negative, or zero.
# 4. Create a function that calculates the square of a number and call it with different inputs.
# 5. Handle a division by zero error using a try-except block.
#
# ---

# %% [markdown]
# This introduction is designed to be welcoming and not overwhelming, emphasizing the ease of learning Python and its relevance to AI to motivate learners to continue with the course.
